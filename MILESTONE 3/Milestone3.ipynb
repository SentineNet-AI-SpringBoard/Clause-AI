# %%
import time
import uuid
from datetime import datetime
from typing import TypedDict, Dict, List

# LangGraph
from langgraph.graph import StateGraph, START, END

# Vector DB
import chromadb
from chromadb.config import Settings

# %%
class ContractState(TypedDict):
    contract_id: str
    contract_text: str
    legal: Dict
    compliance: Dict
    finance: Dict
    operations: Dict
    start_time: float
    end_time: float

# %%
def legal_agent(state: ContractState):
    time.sleep(1)
    return {
        "risk_level": "medium",
        "issues": ["Termination clause ambiguity"],
        "confidence": 0.85
    }

def compliance_agent(state: ContractState):
    time.sleep(1)
    return {
        "risk_level": "medium",
        "issues": ["Missing data privacy clause"],
        "confidence": 0.80
    }

def finance_agent(state: ContractState):
    time.sleep(1)
    return {
        "risk_level": "medium",
        "issues": ["Penalty escalation risk"],
        "confidence": 0.82
    }

def operations_agent(state: ContractState):
    time.sleep(1)
    return {
        "risk_level": "low",
        "issues": [],
        "confidence": 0.90
    }

# %%
graph = StateGraph(ContractState)

graph.add_node("legal", legal_agent)
graph.add_node("compliance", compliance_agent)
graph.add_node("finance", finance_agent)
graph.add_node("operations", operations_agent)

graph.add_edge(START, "legal")
graph.add_edge(START, "compliance")
graph.add_edge(START, "finance")
graph.add_edge(START, "operations")

graph.add_edge("legal", END)
graph.add_edge("compliance", END)
graph.add_edge("finance", END)
graph.add_edge("operations", END)

# %%
contract_graph = graph.compile()

# %%
state = {
    "contract_id": "C-001",
    "contract_text": "Sample contract text",
    "start_time": time.time()
}

parallel_result = contract_graph.invoke(state)
state["end_time"] = time.time()

print("Parallel Runtime:", state["end_time"] - state["start_time"])
# Out:
# Parallel Runtime: 1.0062987804412842

# %%
from chromadb import Client
from chromadb.config import Settings
import os

persist_dir = "./memory"
os.makedirs(persist_dir, exist_ok=True)

# New-style initialization without the deprecated parameter
client = Client(Settings(
    persist_directory=persist_dir,
    is_persistent=True   # tell Chroma you want persistence
))

collection = client.get_or_create_collection("agent_memory")
print("Initialized ChromaDB client!")
# Out:
# Initialized ChromaDB client!

# %%
def store_agent_output(agent, output, contract_id):
    collection.add(
        documents=[str(output)],
        metadatas=[{
            "agent": agent,
            "contract_id": contract_id,
            "risk_level": output.get("risk_level"),  # use get to avoid KeyError
            "confidence": output.get("confidence", None),  # default to None if missing
            "timestamp": datetime.utcnow().isoformat()
        }],
        ids=[str(uuid.uuid4())]
    )

# %%
# Iterate over the keys you want to store
expected_keys = ["legal", "compliance", "finance", "operations"]

for key in expected_keys:
    data = parallel_result.get(key)
    if data:  # Only call if data exists and is not empty
        store_agent_output(key, data, "C-001")
    else:
        print(f"Warning: '{key}' not found or empty in parallel_result")
# Out:
# Warning: 'legal' not found or empty in parallel_result
# Warning: 'compliance' not found or empty in parallel_result
# Warning: 'finance' not found or empty in parallel_result
# Warning: 'operations' not found or empty in parallel_result

# %%
def query_memory(agent=None):
    where = {"agent": agent} if agent else {}
    return collection.get(where=where)

# %%
legal_memory = query_memory("legal")
finance_memory = query_memory("finance")

# %%
# Query all memory safely
all_mem = collection.get(
    where=None,  # no filter
    include=["metadatas", "documents"]
)

# Extract metadata safely
metadatas = all_mem.get("metadatas", [])

# Build shared context string
shared_context = "\n".join([
    f"{m.get('agent', 'Unknown')} risk: {m.get('risk_level', 'N/A')}"
    for m in metadatas
])

print(shared_context)

# %%
from datetime import datetime
import uuid
import time

def store_agent_output(agent, output, contract_id, collection, retries=3, chunk_size=1000):
    """
    Safely stores agent output into a vector collection with retry logic.

    Parameters:
    - agent: Name of the agent (string)
    - output: Dictionary with keys like 'risk_level', 'confidence', 'reason', etc.
    - contract_id: ID of the contract
    - collection: Vector collection object with .add() method
    - retries: Number of times to retry on timeout
    - chunk_size: Max size of each document chunk
    """
    
    # Convert output to string and split into chunks if large
    output_str = str(output)
    chunks = [output_str[i:i+chunk_size] for i in range(0, len(output_str), chunk_size)]
    
    for chunk in chunks:
        for attempt in range(retries):
            try:
                collection.add(
                    documents=[chunk],
                    metadatas=[{
                        "agent": agent,
                        "contract_id": contract_id,
                        "risk_level": output.get("risk_level"),
                        "confidence": output.get("confidence"),  # will store None if missing
                        "timestamp": datetime.utcnow().isoformat()
                    }],
                    ids=[str(uuid.uuid4())]
                )
                break  # success, move to next chunk
            except Exception as e:
                if "timeout" in str(e).lower() or "ReadTimeout" in str(e):
                    print(f"[WARNING] Timeout occurred, retrying {attempt+1}/{retries}...")
                    time.sleep(2)  # wait before retry
                else:
                    raise  # re-raise other exceptions

# %%
from typing import TypedDict, Optional

class GraphState(TypedDict):
    contract_text: str
    legal: Optional[dict]
    finance: Optional[dict]
    compliance: Optional[dict]
    operations: Optional[dict]
    shared_context: Optional[str]

# %%
def build_shared_context(all_agent_memory):
    return "\n".join([
        f"{m.metadata['agent']} risk: {m.metadata['risk_level']}"
        for m in all_agent_memory.matches
    ])

# %%
def refined_legal_agent(state: GraphState):
    shared_context = state["shared_context"]

    refined_output = {
        "risk_level": "high",
        "reason": "Termination clause combined with financial penalties",
        "confidence": 0.88
    }

    return {"legal": refined_output}

# %%
graph.add_node("refined_legal", refined_legal_agent)
graph.add_edge("memory_retrieval", "refined_legal")
graph.add_edge("refined_legal", END)
# Out:
# Adding a node to a graph that has already been compiled. This will not be reflected in the compiled graph.
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.

# %%
from datetime import datetime

refined_legal = {
    "risk_level": "high",
    "reason": "Termination clause combined with financial penalties",
    "confidence": 0.90,
    "refined": True,
    "stage": "refinement",
    "updated_at": datetime.utcnow().isoformat()
}

refined_compliance = {
    "risk_level": "high",
    "reason": "Finance penalty risk escalates compliance exposure",
    "confidence": 0.88,
    "refined": True,
    "stage": "refinement",
    "updated_at": datetime.utcnow().isoformat()
}

store_agent_output("legal", refined_legal, "C-001", collection)
store_agent_output("compliance", refined_compliance, "C-001", collection)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18264\2832748393.py:9: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "updated_at": datetime.utcnow().isoformat()
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18264\2832748393.py:18: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "updated_at": datetime.utcnow().isoformat()
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18264\1138597521.py:32: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat()
# C:\Users\KIIT\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz:  64%|██████▍   | 50.8M/79.3M [30:55<17:23, 28.7kiB/s]
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     126 with map_httpcore_exceptions():
# --> 127     for part in self._httpcore_stream:
#     128         yield part
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     406 self.close()
# --> 407 raise exc from None
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     402 try:
# --> 403     for part in self._stream:
#     404         yield part
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     341     self.close()
# --> 342 raise exc
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     333 with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334     for chunk in self._connection._receive_response_body(**kwargs):
#     335         yield chunk
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# The above exception was the direct cause of the following exception:
#
# ReadError                                 Traceback (most recent call last)
# Cell In[43], line 21
#       3 refined_legal = {
#       4     "risk_level": "high",
#       5     "reason": "Termination clause combined with financial penalties",
#    (...)      9     "updated_at": datetime.utcnow().isoformat()
#      10 }
#      12 refined_compliance = {
#      13     "risk_level": "high",
#      14     "reason": "Finance penalty risk escalates compliance exposure",
#    (...)     18     "updated_at": datetime.utcnow().isoformat()
#      19 }
# ---> 21 store_agent_output("legal", refined_legal, "C-001", collection)
#      22 store_agent_output("compliance", refined_compliance, "C-001", collection)
#
# Cell In[34], line 25, in store_agent_output(agent, output, contract_id, collection, retries, chunk_size)
#      23 for attempt in range(retries):
#      24     try:
# ---> 25         collection.add(
#      26             documents=[chunk],
#      27             metadatas=[{
#      28                 "agent": agent,
#      29                 "contract_id": contract_id,
#      30                 "risk_level": output.get("risk_level"),
#      31                 "confidence": output.get("confidence"),  # will store None if missing
#      32                 "timestamp": datetime.utcnow().isoformat()
#      33             }],
#      34             ids=[str(uuid.uuid4())]
#      35         )
#      36         break  # success, move to next chunk
#      37     except Exception as e:
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\chromadb\api\models\Collection.py:106, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#      71 def add(
#      72     self,
#      73     ids: OneOrMany[ID],
#    (...)     83     uris: Optional[OneOrMany[URI]] = None,
#      84 ) -> None:
#      85     """Add embeddings to the data store.
#      86     Args:
#      87         ids: The ids of the embeddings you wish to add
#    (...)    103
#     104     """
# --> 106     add_request = self._validate_and_prepare_add_request(
#     107         ids=ids,
#     108         embeddings=embeddings,
#     109         metadatas=metadatas,
#     110         documents=documents,
#     111         images=images,
#     112         uris=uris,
#     113     )
#     115     self._client._add(
#     116         collection_id=self.id,
#     117         ids=add_request["ids"],
#    (...)    123         database=self.database,
#     124     )
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\chromadb\api\models\CollectionCommon.py:103, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#     100 @functools.wraps(func)
#     101 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#     102     try:
# --> 103         return func(self, *args, **kwargs)
#     104     except Exception as e:
#     105         msg = f"{str(e)} in {name}."
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\chromadb\api\models\CollectionCommon.py:241, in CollectionCommon._validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     239 if add_records["embeddings"] is None:
#     240     validate_record_set_for_embedding(record_set=add_records)
# --> 241     add_embeddings = self._embed_record_set(record_set=add_records)
#     242 else:
#     243     add_embeddings = add_records["embeddings"]
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\chromadb\api\models\CollectionCommon.py:724, in CollectionCommon._embed_record_set(self, record_set, embeddable_fields, is_query)
#     719             return self._embed(
#     720                 input=self._data_loader(uris=cast(URIs, record_set[field])),  # type: ignore[literal-required]
#     721                 is_query=is_query,
#     722             )
#     723         else:
# --> 724             return self._embed(
#     725                 input=record_set[field],  # type: ignore[literal-required]
#     726                 is_query=is_query,
#     727             )
#     728 raise ValueError(
#     729     "Record does not contain any non-None fields that can be embedded."
#     730     f"Embeddable Fields: {embeddable_fields}"
#     731     f"Record Fields: {record_set}"
#     732 )
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\chromadb\api\models\CollectionCommon.py:748, in CollectionCommon._embed(self, input, is_query)
#     746         return config_ef.embed_query(input=input)
#     747     else:
# --> 748         return config_ef(input=input)
#     749 schema = self.schema
#     750 schema_embedding_function: Optional[EmbeddingFunction[Embeddable]] = None
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\chromadb\api\types.py:809, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     808 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 809     result = call(self, input)
#     810     assert result is not None
#     811     return validate_embeddings(cast(Embeddings, normalize_embeddings(result)))
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\chromadb\api\types.py:939, in DefaultEmbeddingFunction.__call__(self, input)
#     933 def __call__(self, input: Documents) -> Embeddings:
#     934     # Import here to avoid circular imports
#     935     from chromadb.utils.embedding_functions.onnx_mini_lm_l6_v2 import (
#     936         ONNXMiniLM_L6_V2,
#     937     )
# --> 939     return ONNXMiniLM_L6_V2()(input)
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\chromadb\api\types.py:809, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     808 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 809     result = call(self, input)
#     810     assert result is not None
#     811     return validate_embeddings(cast(Embeddings, normalize_embeddings(result)))
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:270, in ONNXMiniLM_L6_V2.__call__(self, input)
#     259 """
#     260 Generate embeddings for the given documents.
#     261
#    (...)    266     Embeddings for the documents.
#     267 """
#     269 # Only download the model when it is actually used
# --> 270 self._download_model_if_not_exists()
#     272 # Generate embeddings
#     273 embeddings = self._forward(input)
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:308, in ONNXMiniLM_L6_V2._download_model_if_not_exists(self)
#     301 os.makedirs(self.DOWNLOAD_PATH, exist_ok=True)
#     302 if not os.path.exists(
#     303     os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME)
#     304 ) or not _verify_sha256(
#     305     os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     306     self._MODEL_SHA256,
#     307 ):
# --> 308     self._download(
#     309         url=self.MODEL_DOWNLOAD_URL,
#     310         fname=os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     311     )
#     312 with tarfile.open(
#     313     name=os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     314     mode="r:gz",
#     315 ) as tar:
#     316     if sys.version_info >= (3, 12):
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\tenacity\__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\tenacity\__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:116, in ONNXMiniLM_L6_V2._download(self, url, fname, chunk_size)
#     108 total = int(resp.headers.get("content-length", 0))
#     109 with open(fname, "wb") as file, self.tqdm(
#     110     desc=str(fname),
#     111     total=total,
#    (...)    114     unit_divisor=1024,
#     115 ) as bar:
# --> 116     for data in resp.iter_bytes(chunk_size=chunk_size):
#     117         size = file.write(data)
#     118         bar.update(size)
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpx\_transports\default.py:126, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
# --> 126     with map_httpcore_exceptions():
#     127         for part in self._httpcore_stream:
#     128             yield part
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     160     value = typ()
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#     167     return exc is not value
#
# File c:\Users\KIIT\Desktop\CLAUSEAI\env\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ReadError: [WinError 10054] An existing connection was forcibly closed by the remote host in add.

# %%
FINAL_CONTRACT_SCHEMA = {
    "contract_id": "C-001",
    "legal": refined_legal,
    "compliance": refined_compliance,
    "finance": parallel_result["finance"],
    "operations": parallel_result["operations"],
    "overall_risk": "high",
    "confidence_score": 0.84,
    "high_risk_clauses": [
        "Termination penalties",
        "Missing privacy clause"
    ],
    "generated_at": datetime.utcnow().isoformat()
}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 5
#       1 FINAL_CONTRACT_SCHEMA = {
#       2     "contract_id": "C-001",
#       3     "legal": refined_legal,
#       4     "compliance": refined_compliance,
# ----> 5     "finance": parallel_result["finance"],
#       6     "operations": parallel_result["operations"],
#       7     "overall_risk": "high",
#       8     "confidence_score": 0.84,
#       9     "high_risk_clauses": [
#      10         "Termination penalties",
#      11         "Missing privacy clause"
#      12     ],
#      13     "generated_at": datetime.utcnow().isoformat()
#      14 }
#
# KeyError: 'finance'

# %%
def generate_report(final_json, tone="executive"):
    return f"""
EXECUTIVE SUMMARY
• Overall Risk: {final_json['overall_risk']}
• Confidence: {final_json['confidence_score']}

LEGAL
• {final_json['legal']}

COMPLIANCE
• {final_json['compliance']}

FINANCE
• {final_json['finance']}

OPERATIONS
• {final_json['operations']}

RECOMMENDATIONS
• Review high-risk clauses
• Apply mitigation controls
"""

# %%
from fastapi import FastAPI, UploadFile, File, HTTPException

app = FastAPI(title="Contract Analysis API")

# %%
@app.post("/analyze")
async def analyze_contract(file: UploadFile = File(...), tone: str="executive"):
    if not file.filename:
        raise HTTPException(status_code=400, detail="Empty file")

    text = (await file.read()).decode("utf-8")

    # Run pipeline (reuse logic above)
    final_json = FINAL_CONTRACT_SCHEMA
    report = generate_report(final_json, tone)

    return {
        "contract_id": final_json["contract_id"],
        "generated_at": final_json["generated_at"],
        "analysis": final_json,
        "report": report
    }

# %%
if contracts:
    for c in contracts:
        st.success(f"Uploaded: {c['name']}")
        st.info(f"Size: {c['size']} bytes | Characters: {c['chars']}")

        with st.expander(f"Preview {c['name']}"):
            st.text(c["text"][:1500])
else:
    st.warning("No valid contract files uploaded.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 if contracts:
#       2     for c in contracts:
#       3         st.success(f"Uploaded: {c['name']}")
#
# NameError: name 'contracts' is not defined

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\KIIT\\Desktop\\master_clauses.csv")
print(df.head())
# Out:
#                                             Filename  \
# 0  CybergyHoldingsInc_20140520_10-Q_EX-10.27_8605...
# 1  EuromediaHoldingsCorp_20070215_10SB12G_EX-10.B...
# 2  FulucaiProductionsLtd_20131223_10-Q_EX-10.9_83...
# 3  GopageCorp_20140221_10-K_EX-10.1_8432966_EX-10...
# 4  IdeanomicsInc_20160330_10-K_EX-10.26_9512211_E...
#
#                                     Document Name  \
# 0               ['MARKETING AFFILIATE AGREEMENT']
# 1   ['VIDEO-ON-DEMAND CONTENT LICENSE AGREEMENT']
# 2  ['CONTENT DISTRIBUTION AND LICENSE AGREEMENT']
# 3           ['WEBSITE CONTENT LICENSE AGREEMENT']
# 4                   ['CONTENT LICENSE AGREEMENT']
#
#                          Document Name-Answer  \
# 0               MARKETING AFFILIATE AGREEMENT
# 1   VIDEO-ON-DEMAND CONTENT LICENSE AGREEMENT
# 2  CONTENT DISTRIBUTION AND LICENSE AGREEMENT
# 3           WEBSITE CONTENT LICENSE AGREEMENT
# 4                   CONTENT LICENSE AGREEMENT
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 83 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Filename                                    510 non-null    object
#  1   Document Name                               510 non-null    object
#  2   Document Name-Answer                        510 non-null    object
#  3   Parties                                     510 non-null    object
#  4   Parties-Answer                              509 non-null    object
#  5   Agreement Date                              510 non-null    object
#  6   Agreement Date-Answer                       465 non-null    object
#  7   Effective Date                              510 non-null    object
#  8   Effective Date-Answer                       359 non-null    object
#  9   Expiration Date                             510 non-null    object
# ...

# %%
df.describe()
# Out:
#                                                  Filename  \
# count                                                 510
# unique                                                510
# top     KUBIENT,INC_07_02_2020-EX-10.14-MASTER SERVICE...
# freq                                                    1
#
#                     Document Name   Document Name-Answer  \
# count                         510                    510
# unique                        274                    285
# top     ['SPONSORSHIP AGREEMENT']  SPONSORSHIP AGREEMENT
# freq                           21                     20
#
#                                                   Parties  \
# count                                                 510
# unique                                                502
# top     ['Adviser', 'FASC', 'FEDERATED ADVISORY SERVIC...
# freq                                                    4
#
#                                            Parties-Answer Agreement Date  \
# ...

# %%
clause_cols = [col for col in df.columns if col.endswith("-Answer")]
clause_freq = df[clause_cols].apply(lambda x: x.value_counts())
print(clause_freq.T)
# Out:
#                                                                       CONTENT LICENSE AGREEMENT  \
# Document Name-Answer                                                                    1.0
# Parties-Answer                                                                          NaN
# Agreement Date-Answer                                                                   NaN
# Effective Date-Answer                                                                   NaN
# Expiration Date-Answer                                                                  NaN
# Renewal Term-Answer                                                                     NaN
# Governing Law-Answer                                                                    NaN
# Most Favored Nation-Answer                                                              NaN
# Competitive Restriction Exception-Answer                                                NaN
# ...

# %%
clause_freq = df[clause_cols].apply(lambda x: x.value_counts())
print(clause_freq.T)
# Out:
#                                                                       CONTENT LICENSE AGREEMENT  \
# Document Name-Answer                                                                    1.0
# Parties-Answer                                                                          NaN
# Agreement Date-Answer                                                                   NaN
# Effective Date-Answer                                                                   NaN
# Expiration Date-Answer                                                                  NaN
# Renewal Term-Answer                                                                     NaN
# Governing Law-Answer                                                                    NaN
# Most Favored Nation-Answer                                                              NaN
# Competitive Restriction Exception-Answer                                                NaN
# ...

# %%
clause_presence = (df[clause_cols] == "Yes").mean().sort_values(ascending=False)
print(clause_presence)
# Out:
# Anti-Assignment-Answer                      0.733333
# Cap On Liability-Answer                     0.539216
# License Grant-Answer                        0.500000
# Audit Rights-Answer                         0.419608
# Termination For Convenience-Answer          0.358824
# Post-Termination Services-Answer            0.356863
# Exclusivity-Answer                          0.352941
# Insurance-Answer                            0.327451
# Revenue/Profit Sharing-Answer               0.325490
# Minimum Commitment-Answer                   0.323529
# Non-Transferable License-Answer             0.270588
# Ip Ownership Assignment-Answer              0.243137
# Change Of Control-Answer                    0.237255
# Non-Compete-Answer                          0.233333
# Uncapped Liability-Answer                   0.217647
# Covenant Not To Sue-Answer                  0.196078
# Rofr/Rofo/Rofn-Answer                       0.166667
# Volume Restriction-Answer                   0.160784
# ...

# %%
clause_presence = (df[clause_cols] == "Yes").mean().sort_values(ascending=False)
print(clause_presence)
# Out:
# Anti-Assignment-Answer                      0.733333
# Cap On Liability-Answer                     0.539216
# License Grant-Answer                        0.500000
# Audit Rights-Answer                         0.419608
# Termination For Convenience-Answer          0.358824
# Post-Termination Services-Answer            0.356863
# Exclusivity-Answer                          0.352941
# Insurance-Answer                            0.327451
# Revenue/Profit Sharing-Answer               0.325490
# Minimum Commitment-Answer                   0.323529
# Non-Transferable License-Answer             0.270588
# Ip Ownership Assignment-Answer              0.243137
# Change Of Control-Answer                    0.237255
# Non-Compete-Answer                          0.233333
# Uncapped Liability-Answer                   0.217647
# Covenant Not To Sue-Answer                  0.196078
# Rofr/Rofo/Rofn-Answer                       0.166667
# Volume Restriction-Answer                   0.160784
# ...

# %%
import sys
# !{sys.executable} -m pip install pandas matplotlib wordcloud nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from tqdm import tqdm
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
folder_path = r"C:\Users\KIIT\Desktop\ClauseAI\DATA\RAW\full_contract_txt"
files = [f for f in os.listdir(folder_path) if f.endswith(".txt")]
len(files)
# Out:
# 510

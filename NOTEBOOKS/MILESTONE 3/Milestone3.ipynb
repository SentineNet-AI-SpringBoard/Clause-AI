# %%
#

# %%
import time
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor

import faiss
from sentence_transformers import SentenceTransformer

# %%
def legal_agent(chunks):
    start = time.time()
    results = []
    for c in chunks:
        if "terminate" in c["text"].lower():
            results.append({"contract_id": c["contract_id"], "issue": "Termination clause found"})
    print(f"[Legal Agent] Finished in {time.time() - start:.2f}s")
    return {"legal": results}

def compliance_agent(chunks):
    start = time.time()
    results = []
    for c in chunks:
        if "indemnify" in c["text"].lower():
            results.append({"contract_id": c["contract_id"], "issue": "Indemnity clause found"})
    print(f"[Compliance Agent] Finished in {time.time() - start:.2f}s")
    return {"compliance": results}

def finance_agent(chunks):
    start = time.time()
    results = []
    for c in chunks:
        if "invoice" in c["text"].lower() or "payment" in c["text"].lower():
            results.append({"contract_id": c["contract_id"], "issue": "Payment clause found"})
    print(f"[Finance Agent] Finished in {time.time() - start:.2f}s")
    return {"finance": results}
